# %%
conda install urllib
# Out:
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - urllib
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
y = json.dumps(http://127.0.0.1:5000/vg_data)
y
# Out:
#   File "<ipython-input-4-ce6e4049631b>", line 1
#     y = json.dumps(http://127.0.0.1:5000/vg_data)
#                        ^
# SyntaxError: invalid syntax

# %%
>>> read_from_url = urllib.some_method_open(this_file)
>>> my_dict = json.load(read_from_url)
>>> print(my_dict['some_key'])
some value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a60489f9c51e> in <module>
#       1 import urllib, json, requests
#       2 url = "http://127.0.0.1:5000/vg_data"
# ----> 3 response = urllib.urlopen(url)
#       4 data = json.loads(response.read())
#       5 print(data)
#
# AttributeError: module 'urllib' has no attribute 'urlopen'

# %%
read_from_url = urllib.some_method_open("http://127.0.0.1:5000/vg_data")
read_from_url
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-03a3adf1e46c> in <module>
# ----> 1 read_from_url = urllib.some_method_open("http://127.0.0.1:5000/vg_data")
#       2 read_from_url
#
# AttributeError: module 'urllib' has no attribute 'some_method_open'

# %%
import requests
import json
response = json.loads(requests.get("http://127.0.0.1:5000/vg_data").text)
response[0]["vg_data"]
# Out:
# [{'EU_Sales': 30000.0,
#   'Genre': 'Action',
#   'Global_Sales': 670000,
#   'JP_Sales': 0.0,
#   'Mean': False,
#   'Median': False,
#   'NA_Sales': 630000.0,
#   'Name': 'ADVENTURES OF TRON',
#   'Other_Sales': 10000.0,
#   'Platform': '2600',
#   'Price': 16.1,
#   'Publisher': 'Mattel Interactive',
#   'Year': 1981},
#  {'EU_Sales': 20000.0,
#   'Genre': 'Action',
#   'Global_Sales': 390000,
#   'JP_Sales': 0.0,
#   'Mean': False,
#   'Median': False,
#   'NA_Sales': 360000.0,
#   'Name': 'AIRLOCK',
#   'Other_Sales': 0.0,
#   'Platform': '2600',
#   'Price': 17.0,
#   'Publisher': 'Data Age',
#   'Year': 1981},
#  {'EU_Sales': 40000.0,
#   'Genre': 'Action',
#   'Global_Sales': 790000,
#   'JP_Sales': 0.0,
#   'Mean': True,
#   'Median': True,
#   'NA_Sales': 740000.0,
#   'Name': 'ALIEN',
#   'Other_Sales': 10000.0,
#   'Platform': '2600',
#   'Price': 61.24,
#   'Publisher': '20th Century Fox Video Games',
#   'Year': 1981},
#  {'EU_Sales': 10000.0,
#   'Genre': 'Action',
# ...
